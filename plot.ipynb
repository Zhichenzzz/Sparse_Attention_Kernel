# %%
import pandas as pd
import matplotlib.pyplot as plt  

# 读取CSV文件
file_path = 'sparse_attn/test_topk_opt1/fused-attention-batch4-head32-d128-fwd-causal=True.csv'
df = pd.read_csv(file_path)

df = df.iloc[:50]  

# df['topk'] = df['topk'].apply(lambda x: float(x)/256)
df['Speedup'] = df['Flash-2'] / df['Triton [FP16]']
df['Ideal'] = df['topk'].apply(lambda x: 128/x if x != 0.0 else None)
pd.set_option('display.max_rows', 200)  # 设置显示所有行

df['ratio'] = df['Speedup'] / df['Ideal']
# 选择需要的列  
df_selected = df[['topk', 'Speedup', 'Ideal', 'ratio']]
  
# 创建一个包含两个子图的图表  
fig, ax1 = plt.subplots(figsize=(10, 6))  
  
# 绘制第一个子图 (主图)  
ax1.plot(df_selected['topk'], df_selected['Speedup'], label='Speedup', marker='o')  
ax1.plot(df_selected['topk'], df_selected['Ideal'], label='Ideal', marker='x')  
ax1.set_xlabel('topk')  
ax1.set_ylabel('Speedup')  
ax1.set_title('Speedup and Ideal via topk')  
ax1.legend()  
  
# 创建第二个子图 (嵌入小图)  
ax2 = fig.add_axes([0.6, 0.3, 0.25, 0.4])  # [left, bottom, width, height]  
ax2.plot(df_selected['topk'], df_selected['ratio'], label='Speedup/Ideal', marker='*', color='green')  
ax2.set_xlabel('topk')  
ax2.set_ylabel('Ratio')  
ax2.set_title('Speedup / Ideal')  
ax2.legend()  
  
# 显示图表  
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt  

# 读取CSV文件
file_path = 'sparse_attn/test_topk_opt1_8k/fused-attention-batch4-head32-d128-fwd-causal=True.csv'
df = pd.read_csv(file_path)

df = df.iloc[:50]  

# df['topk'] = df['topk'].apply(lambda x: float(x)/256)
df['Speedup'] = df['Flash-2'] / df['Triton [FP16]']
df['Ideal'] = df['topk'].apply(lambda x: 64/x if x != 0.0 else None)
pd.set_option('display.max_rows', 200)  # 设置显示所有行

df['ratio'] = df['Speedup'] / df['Ideal']
# 选择需要的列  
df_selected = df[['topk', 'Speedup', 'Ideal', 'ratio']]
  
# 创建一个包含两个子图的图表  
fig, ax1 = plt.subplots(figsize=(10, 6))  
  
# 绘制第一个子图 (主图)  
ax1.plot(df_selected['topk'], df_selected['Speedup'], label='Speedup', marker='o')  
ax1.plot(df_selected['topk'], df_selected['Ideal'], label='Ideal', marker='x')  
ax1.set_xlabel('topk')  
ax1.set_ylabel('Speedup')  
ax1.set_title('Speedup and Ideal via topk')  
ax1.legend()  
  
# 创建第二个子图 (嵌入小图)  
ax2 = fig.add_axes([0.6, 0.3, 0.25, 0.4])  # [left, bottom, width, height]  
ax2.plot(df_selected['topk'], df_selected['ratio'], label='Speedup/Ideal', marker='*', color='green')  
ax2.set_xlabel('topk')  
ax2.set_ylabel('Ratio')  
ax2.set_title('Speedup / Ideal')  
ax2.legend()  
  
# 显示图表  
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt  

# 读取CSV文件
file_path = 'sparse_attn/test_topk_opt1_12k/fused-attention-batch4-head32-d128-fwd-causal=True.csv'
df = pd.read_csv(file_path)

df = df.iloc[:50]  

# df['topk'] = df['topk'].apply(lambda x: float(x)/256)
df['Speedup'] = df['Flash-2'] / df['Triton [FP16]']
df['Ideal'] = df['topk'].apply(lambda x: 96/x if x != 0.0 else None)
pd.set_option('display.max_rows', 200)  # 设置显示所有行

df['ratio'] = df['Speedup'] / df['Ideal']
# 选择需要的列  
df_selected = df[['topk', 'Speedup', 'Ideal', 'ratio']]
  
# 创建一个包含两个子图的图表  
fig, ax1 = plt.subplots(figsize=(10, 6))  
  
# 绘制第一个子图 (主图)  
ax1.plot(df_selected['topk'], df_selected['Speedup'], label='Speedup', marker='o')  
ax1.plot(df_selected['topk'], df_selected['Ideal'], label='Ideal', marker='x')  
ax1.set_xlabel('topk')  
ax1.set_ylabel('Speedup')  
ax1.set_title('Speedup and Ideal via topk')  
ax1.legend()  
  
# 创建第二个子图 (嵌入小图)  
ax2 = fig.add_axes([0.6, 0.3, 0.25, 0.4])  # [left, bottom, width, height]  
ax2.plot(df_selected['topk'], df_selected['ratio'], label='Speedup/Ideal', marker='*', color='green')  
ax2.set_xlabel('topk')  
ax2.set_ylabel('Ratio')  
ax2.set_title('Speedup / Ideal')  
ax2.legend()  
  
# 显示图表  
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt  

# 读取CSV文件
file_path = '/home/v-zhizeng/Sparse_Atten_Kernel/sparse_attention/sparse_attn_16k/sparse-attention-batch4-head32-seq16384-causal=True.csv'
file_2 = '/home/v-zhizeng/Sparse_Atten_Kernel/predictor_kernel/mask_predictor/mask_predictor-batch4-hidden256-Seq16384-fwd.csv'
df1 = pd.read_csv(file_path)
df2 = pd.read_csv(file_2)

df1
df1['Ratio'] = df1['topk'].apply(lambda x: x/128 *100)
df2['Ratio'] = df2['topk'].apply(lambda x: x/128 *100)
df1['Speedup'] = df1['Flash-2'] / df1['Triton [FP16]']
df2['Speedup'] = df2['Torch-fp16'] / df2['Triton-fp16']

df3 = pd.merge(df1, df2, on='Ratio', how='inner')
df3
# df3 = df3[['Ratio', 'Speedup_x', 'Speedup_y']]
df3['sparse_attn'] = df3['Triton [FP16]'] + df3['Triton-fp16']
df3['full_attn'] = df3['Flash-2']
df3['Speedup'] = df3['full_attn'] / df3['sparse_attn']
df3 = df3[['Ratio', 'sparse_attn', 'full_attn','Speedup']]
df3= df3.iloc[1:]
# 创建图表
plt.figure(figsize=(10, 6))
plt.plot(df3['Ratio'], df3['Speedup'], marker='o')

# 添加标题和标签
# plt.title('Sparse Attention Speedup compared to Full Attention (flashattention-2)')
plt.xlabel('None-zero Ratio (%)', fontsize=14, fontweight='bold')
plt.ylabel('Speedup', fontsize=14, fontweight='bold')
# 加粗坐标轴
ax = plt.gca()  # 获取当前坐标轴
ax.spines['top'].set_linewidth(1.5)
ax.spines['right'].set_linewidth(1.5)
ax.spines['bottom'].set_linewidth(1.5)
ax.spines['left'].set_linewidth(1.5)

# 加粗坐标轴刻度
ax.tick_params(axis='both', which='major', labelsize=12, width=1.5)

# 反转x轴
plt.xlim(0, 50)

plt.gca().invert_xaxis()
plt.axhline(y=1, color='r', linestyle='--')

# 显示图表
plt.grid(True)
plt.ylim(0, 20)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt  

# 读取CSV文件
file_path = '/home/v-zhizeng/Sparse_Atten_Kernel/sparse_attention/sparse_attn_32k/sparse-attention-batch4-head32-seq32768-causal=True.csv'
file_2 = '/home/v-zhizeng/Sparse_Atten_Kernel/predictor_kernel/mask_predictor/mask_predictor-batch4-hidden256-Seq32768-fwd.csv'
df1 = pd.read_csv(file_path)
df2 = pd.read_csv(file_2)

df1
df1['Ratio'] = df1['topk'].apply(lambda x: x/256 *100)
df2['Ratio'] = df2['topk'].apply(lambda x: x/256 *100)
df1['Speedup'] = df1['Flash-2'] / df1['Triton [FP16]']
df2['Speedup'] = df2['Torch-fp16'] / df2['Triton-fp16']

df3 = pd.merge(df1, df2, on='Ratio', how='inner')
# df3 = df3[['Ratio', 'Speedup_x', 'Speedup_y']]
df3['sparse_attn'] = df3['Triton [FP16]'] + df3['Triton-fp16']
df3['full_attn'] = df3['Flash-2'] + df3['Torch-fp16']
df3['Speedup'] = df3['full_attn'] / df3['sparse_attn']
df3 = df3[['Ratio', 'sparse_attn', 'full_attn','Speedup']]
df3= df3.iloc[1:26]
# 创建图表
plt.figure(figsize=(10, 6))
plt.plot(df3['Ratio'], df3['Speedup'], marker='o')

# 添加标题和标签
# plt.title('Sparse Attention Speedup compared to Full Attention (flashattention-2)')
plt.xlabel('None-zero Ratio (%)', fontsize=14, fontweight='bold')
plt.ylabel('Speedup', fontsize=14, fontweight='bold')
# 加粗坐标轴
ax = plt.gca()  # 获取当前坐标轴
ax.spines['top'].set_linewidth(1.5)
ax.spines['right'].set_linewidth(1.5)
ax.spines['bottom'].set_linewidth(1.5)
ax.spines['left'].set_linewidth(1.5)

# 加粗坐标轴刻度
ax.tick_params(axis='both', which='major', labelsize=12, width=1.5)

# 反转x轴
plt.xlim(0, 50)

plt.gca().invert_xaxis()
plt.axhline(y=1, color='r', linestyle='--')

# 显示图表
plt.grid(True)
plt.ylim(0, 20)
plt.show()
df3
# Out:
#         Ratio  sparse_attn   full_attn    Speedup
# 1    1.953125    10.281845  186.980410  18.185492
# 2    3.906250    16.210008  187.999515  11.597744
# 3    5.859375    22.145125  188.151015   8.496272
# 4    7.812500    27.981856  188.428914   6.733968
# 5    9.765625    33.798329  188.330442   5.572182
# 6   11.718750    39.522830  188.661983   4.773494
# 7   13.671875    45.469593  189.019316   4.157049
# 8   15.625000    51.067594  188.868248   3.698397
# 9   17.578125    56.850942  188.874455   3.322275
# 10  19.531250    62.149428  191.551361   3.082110
# 11  21.484375    67.597962  193.447758   2.861740
# 12  23.437500    72.932218  192.653673   2.641544
# 13  25.390625    78.307124  194.572404   2.484734
# 14  27.343750    83.577140  194.535246   2.327613
# 15  29.296875    88.781650  194.346345   2.189037
# 16  31.250000    93.877763  192.115831   2.046447
# 17  33.203125    99.754086  192.207453   1.926813
# 18  35.156250   105.174770  192.613256   1.831364
# 19  37.109375   109.566057  191.828202   1.750800
# 20  39.062500   114.562359  191.920183   1.675246
# 21  41.015625   121.318266  192.105654   1.583485
# 22  42.968750   127.286513  191.756167   1.506492
# 23  44.921875   132.593043  190.925528   1.439936
# 24  46.875000   135.205883  191.544858   1.416690
# 25  48.828125   140.725795  191.351330   1.359746

# %%
import torch

m = torch.randn(10, 10)
mask = torch.tril(torch.ones(10, 10))
m[mask == 0] = float('-inf')

print(m)
m = torch.topk(m, 4, dim=1)
print(m)
# Out:
# tensor([[-0.8193,    -inf,    -inf,    -inf,    -inf,    -inf,    -inf,    -inf,
#             -inf,    -inf],
#         [ 0.7103,  2.4369,    -inf,    -inf,    -inf,    -inf,    -inf,    -inf,
#             -inf,    -inf],
#         [-1.5510,  1.0179,  0.2910,    -inf,    -inf,    -inf,    -inf,    -inf,
#             -inf,    -inf],
#         [-0.4283, -0.3237, -0.8236,  1.4793,    -inf,    -inf,    -inf,    -inf,
#             -inf,    -inf],
#         [ 0.2581,  0.1395, -0.3428, -0.2073,  1.3840,    -inf,    -inf,    -inf,
#             -inf,    -inf],
#         [-0.6802, -0.9722,  0.0394, -0.1403, -1.8515, -0.7669,    -inf,    -inf,
#             -inf,    -inf],
#         [-0.4187, -0.2966, -0.2247,  0.7669, -0.3576, -0.2174,  0.1605,    -inf,
#             -inf,    -inf],
#         [-0.4466,  1.1095,  0.7281,  0.2573,  0.5240, -1.5324, -0.1929, -0.6594,
#             -inf,    -inf],
#         [-2.5744,  1.4916, -0.4561,  0.3404, -0.6730,  0.1349, -1.3590, -0.3684,
#          -0.7651,    -inf],
#         [-0.6004,  0.6945, -0.5954,  0.3580,  0.8971, -1.0858,  0.6994, -1.6232,
#           1.0124, -1.8736]])
# torch.return_types.topk(
# values=tensor([[-0.8193,    -inf,    -inf,    -inf],
#         [ 2.4369,  0.7103,    -inf,    -inf],
#         [ 1.0179,  0.2910, -1.5510,    -inf],
#         [ 1.4793, -0.3237, -0.4283, -0.8236],
#         [ 1.3840,  0.2581,  0.1395, -0.2073],
#         [ 0.0394, -0.1403, -0.6802, -0.7669],
#         [ 0.7669,  0.1605, -0.2174, -0.2247],
#         [ 1.1095,  0.7281,  0.5240,  0.2573],
#         [ 1.4916,  0.3404,  0.1349, -0.3684],
#         [ 1.0124,  0.8971,  0.6994,  0.6945]]),
# indices=tensor([[0, 7, 6, 5],
#         [1, 0, 6, 9],
#         [1, 2, 0, 9],
#         [3, 1, 0, 2],
#         [4, 0, 1, 3],
#         [2, 3, 0, 5],
#         [3, 6, 5, 2],
#         [1, 2, 4, 3],
#         [1, 3, 5, 7],
#         [8, 4, 6, 1]]))
