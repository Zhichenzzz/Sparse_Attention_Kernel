# %%
import numpy as np
import matplotlib.pyplot as plt

y_labels = ["Full_attn", 0.5, 0.6, 0.7, 0.8, 0.9]  
total_latency = [788.272817, 696.954265, 557.39791, 419.332796, 281.715447, 144.471042]
part1 = [0, 1.776975, 1.778412,1.778708,1.778826,1.779003]
part2 = [0, 4.364363, 4.258963, 4.21342, 4.16831, 3.029701]  
part3 = [788.272817, 690.812927, 551.360535, 413.340668, 275.768311, 139.662338]  

colors = ['#4682B4', '#ff7f0e', '#2ca02c']
bar_width = 0.75  
gap = 0.05  
indices = np.arange(len(y_labels)) * (1 + gap)  
plt.figure(figsize=(5, 3.5))

plt.barh(indices, part1, label='Attention Gate', color=colors[2], height=bar_width)
plt.barh(indices, part2, left=part1, label='Top-K', color=colors[1], height=bar_width)
plt.barh(indices, part3, left=np.array(part1) + np.array(part2), label='Sparse attention', color=colors[0], height=bar_width)

plt.rc('axes', linewidth=12) 
plt.tick_params(axis='both', which='major', labelsize=12, width=12)  

ax = plt.gca()
ax.spines['top'].set_visible(False)    
ax.spines['right'].set_visible(False) 
ax.spines['bottom'].set_linewidth(2)  
ax.spines['left'].set_linewidth(2)    

ax.tick_params(axis='both', which='major', labelsize=14, width=2)

# plt.ylabel('Sparsity', fontsize=14, fontweight='bold')
plt.xlabel('Latency (ms)', fontsize=16, fontweight='bold')
# plt.title('SeerAttention Kernel Latency Breakdown')

plt.yticks(indices, y_labels)
# plt.xticks([0, 0.8, 1.6, 2.4, 3.2])

plt.grid(axis='x', linestyle='--', linewidth=1.5)

plt.legend(loc='upper right', bbox_to_anchor=(1, 1), ncol=1, fontsize=12)

pdf_filename = "latency_full_128k.pdf"
plt.tight_layout()
plt.savefig(pdf_filename, format='pdf', dpi=300)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

y_labels = ["Full_attn", 0.5, 0.6, 0.7, 0.8, 0.9]  
total_latency = [44.0441842, 696.954265, 557.39791, 419.332796, 281.715447, 144.471042]
total_latency = [44.0441842, 696.954265, 557.39791, 419.332796, 281.715447, 144.471042]
part1 = [0, 0.366285, 0.365935, 0.366277, 0.366142, 0.366121]
part2 = [0, 0.664112, 0.386138, 0.384061, 0.380517, 0.322286]
part3 = [44.0441842, 37.694466, 30.272171, 22.867714, 15.358293, 7.765674]

colors = ['#4682B4', '#ff7f0e', '#2ca02c']
bar_width = 0.75  
gap = 0.05  
indices = np.arange(len(y_labels)) * (1 + gap)  
plt.figure(figsize=(5, 3.5))

plt.barh(indices, part1, label='Attention Gate', color=colors[2], height=bar_width)
plt.barh(indices, part2, left=part1, label='Top-K', color=colors[1], height=bar_width)
plt.barh(indices, part3, left=np.array(part1) + np.array(part2), label='Sparse attention', color=colors[0], height=bar_width)

plt.rc('axes', linewidth=12)  
plt.tick_params(axis='both', which='major', labelsize=12, width=12) 

ax = plt.gca()
ax.spines['top'].set_visible(False)    
ax.spines['right'].set_visible(False) 
ax.spines['bottom'].set_linewidth(2)   
ax.spines['left'].set_linewidth(2)    
ax.tick_params(axis='both', which='major', labelsize=14, width=2)

# plt.ylabel('Sparsity', fontsize=14, fontweight='bold')
plt.xlabel('Latency (ms)', fontsize=16, fontweight='bold')
# plt.title('SeerAttention Kernel Latency Breakdown')

plt.yticks(indices, y_labels)
plt.xticks([0, 12, 24, 36, 48])

plt.grid(axis='x', linestyle='--', linewidth=1.5)

plt.legend(loc='upper right', bbox_to_anchor=(1, 1), ncol=1, fontsize=12)

pdf_filename = "latency_full_32k.pdf"
plt.tight_layout()
plt.savefig(pdf_filename, format='pdf', dpi=300)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

y_labels = ["Full_attn", 0.5, 0.6, 0.7, 0.8, 0.9]  
total_latency = [44.0441842, 696.954265, 557.39791, 419.332796, 281.715447, 144.471042]
part1 = [0, 0.135329, 0.13693, 0.122113, 0.135042, 0.136724]
part2 = [0, 0.055562, 0.041031, 0.056151, 0.041971, 0.036565]
part3 = [2.9493014, 2.415724, 1.923392, 1.439149, 0.989043, 0.511684]

colors = ['#4682B4', '#ff7f0e', '#2ca02c']
bar_width = 0.75  
gap = 0.05  
indices = np.arange(len(y_labels)) * (1 + gap)  
plt.figure(figsize=(5, 3.5))

plt.barh(indices, part1, label='Attention Gate', color=colors[2], height=bar_width)
plt.barh(indices, part2, left=part1, label='Top-K', color=colors[1], height=bar_width)
plt.barh(indices, part3, left=np.array(part1) + np.array(part2), label='Sparse attention', color=colors[0], height=bar_width)

plt.rc('axes', linewidth=12)
plt.tick_params(axis='both', which='major', labelsize=12, width=12) 

ax = plt.gca()
ax.spines['top'].set_visible(False)    
ax.spines['right'].set_visible(False)  
ax.spines['bottom'].set_linewidth(2)  
ax.spines['left'].set_linewidth(2)    

ax.tick_params(axis='both', which='major', labelsize=14, width=2)

plt.ylabel('Sparsity', fontsize=16, fontweight='bold')
plt.xlabel('Latency (ms)', fontsize=16, fontweight='bold')


plt.yticks(indices, y_labels)



plt.grid(axis='x', linestyle='--', linewidth=1.5)

plt.legend(loc='upper right', bbox_to_anchor=(1, 1), ncol=1, fontsize=12)

pdf_filename = "latency_full_8k.pdf"
plt.tight_layout()
plt.savefig(pdf_filename, format='pdf', dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for plotting
seq = np.array([1, 4, 8, 16, 32, 64, 128])
flash = np.array([405, 888, 1532, 2820, 5396, 10548, 20852]) / 1000
pooling = np.array([413, 1018, 2052, 4900, 13716, 25181, 67328]) / 1000
torch = np.array([1532, 17660, 67836, 261943, 1107385, 4439023, 18349032]) / 1000
color_palette = [
    "#1f77b4",  # Medium Blue
    "#2ca02c",  # Green
    "#17becf",  # Cyan/Teal
    "#98df8a",  # Light Green
    "#aec7e8",  # Light Blue
    "#7f7f7f",  # Grayish Blue
    "#8c564b",  # Brownish tone for diversity
    "#d62728",  # Red (to add a slight contrast)
    "#9edae5",  # Very Light Cyan
]

# Recreate plot with the last four points of the Torch line as a dashed line
plt.figure(figsize=(6, 4))

# Plot Flash and Pooling as solid lines
plt.plot(seq, flash, label="FlashAttention", marker='^', linestyle='-', color=color_palette[0],markersize=10,linewidth=2)
plt.plot(seq, pooling, label="Modified FlashAttention", marker='s', linestyle='-', color=color_palette[1],markersize=10,linewidth=2)

# Plot Torch: first three points as solid, last four points as dashed
plt.plot(seq[:3], torch[:3], label="Naive attention with torch", marker='X', linestyle='-', color=color_palette[-2],markersize=10,linewidth=2)
plt.plot(seq[2:], torch[2:], marker='', linestyle='--', color=color_palette[-2],linewidth=2)
plt.axhline(y=80, color='gray', linestyle='--')

plt.text(seq[-3], torch[-3], '     OOM', fontsize=16, fontstyle='italic', color='red', weight='bold')
plt.text(0.8, 95, 'A100 Maximum memory', fontsize=12, color='gray', style='italic')

# Adding legend
plt.legend()

# Display grid and plot
# plt.grid(True)
plt.xscale('log')
plt.yscale('log')
plt.xticks(seq, ['1k', '4k', '8k', '16k', '32k', '64k', '128k'])
ax = plt.gca()  

ax.spines['top'].set_linewidth(1.5)
ax.spines['right'].set_linewidth(1.5)
ax.spines['bottom'].set_linewidth(1.5)
ax.spines['left'].set_linewidth(1.5)

ax.tick_params(axis='both', which='major', labelsize=14, width=2)

plt.ylabel('GPU Memory Usage (GB)', fontsize=16, fontweight='bold')
plt.xlabel('Sequence Length', fontsize=16, fontweight='bold')

ax.tick_params(axis='both', which='major', labelsize=12, width=1.5)
plt.tight_layout()
pdf_filename = "Pooling_memory.pdf"
plt.savefig(pdf_filename, format='pdf', dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for plotting
seq = np.array([1, 4, 8, 16, 32, 64, 128])
flash = np.array([
    0.425366,
    5.873551,
    22.414848,
    88.137726,
    356.502533,
    1479.089111,
    5033.42  # Note: Comma removed for proper float conversion
])
pooling = np.array([
    1.029754,
    13.588625,
    52.026367,
    203.369476,
    804.420593,
    3283.398682,
    13048.63  # Note: Comma removed for proper float conversion
])
torch = np.array([
    2.71341,
    55.405567,
    205.5383,
    823.324,
    3502.862,
    13892.3429,
    54180  # Note: Comma removed for proper float conversion
]
)
color_palette = [
    "#1f77b4",  # Medium Blue
    "#2ca02c",  # Green
    "#17becf",  # Cyan/Teal
    "#98df8a",  # Light Green
    "#aec7e8",  # Light Blue
    "#7f7f7f",  # Grayish Blue
    "#8c564b",  # Brownish tone for diversity
    "#d62728",  # Red (to add a slight contrast)
    "#9edae5",  # Very Light Cyan
]

# Recreate plot with the last four points of the Torch line as a dashed line
plt.figure(figsize=(6, 4))

# Plot Flash and Pooling as solid lines
plt.plot(seq, flash, label="FlashAttention", marker='^', linestyle='-', color=color_palette[0],markersize=10,linewidth=2)
plt.plot(seq, pooling, label="Modified FlashAttention", marker='s', linestyle='-', color=color_palette[1],markersize=10,linewidth=2)

# Plot Torch: first three points as solid, last four points as dashed
plt.plot(seq[:3], torch[:3], label="Naive attention with torch", marker='X', linestyle='-', color=color_palette[-2],markersize=10,linewidth=2)
plt.plot(seq[2:], torch[2:], marker='', linestyle='--', color=color_palette[-2],linewidth=2)
# plt.axhline(y=80, color='gray', linestyle='--')

plt.text(seq[-3], torch[-3], 'OOM      ', fontsize=16, fontstyle='italic', color='red', weight='bold')
# plt.text(0.8, 95, 'A100 Maximum memory', fontsize=12, color='gray', style='italic')

# Adding legend
plt.legend()

# Display grid and plot
# plt.grid(True)
plt.xscale('log')
plt.yscale('log')
plt.xticks(seq, ['1k', '4k', '8k', '16k', '32k', '64k', '128k'])
ax = plt.gca()  

ax.spines['top'].set_linewidth(1.5)
ax.spines['right'].set_linewidth(1.5)
ax.spines['bottom'].set_linewidth(1.5)
ax.spines['left'].set_linewidth(1.5)

ax.tick_params(axis='both', which='major', labelsize=14, width=2)

plt.ylabel('Latency (ms)', fontsize=16, fontweight='bold')
plt.xlabel('Sequence Length', fontsize=16, fontweight='bold')

ax.tick_params(axis='both', which='major', labelsize=12, width=1.5)
plt.tight_layout()
pdf_filename = "Pooling_latency.pdf"
plt.savefig(pdf_filename, format='pdf', dpi=300)
plt.show()
